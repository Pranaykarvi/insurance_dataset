# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r"D:\target\chalnges\kaggle_Regression_with_an_Insurance_Dataset\playground-series-s4e12\train.csv")

# %%
data.head()
# Out:
#    id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   0  19.0  Female        10049.0        Married                   1.0
# 1   1  39.0  Female        31678.0       Divorced                   3.0
# 2   2  23.0    Male        25602.0       Divorced                   3.0
# 3   3  21.0    Male       141855.0        Married                   2.0
# 4   4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level     Occupation  Health Score  Location  ... Previous Claims  \
# 0      Bachelor's  Self-Employed     22.598761     Urban  ...             2.0
# 1        Master's            NaN     15.569731     Rural  ...             1.0
# 2     High School  Self-Employed     47.177549  Suburban  ...             1.0
# 3      Bachelor's            NaN     10.938144     Rural  ...             1.0
# 4      Bachelor's  Self-Employed     20.376094     Rural  ...             0.0
#
# ...

# %%
data=data.drop(columns=['id'])

# %%
data.head()
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
# 3  21.0    Male       141855.0        Married                   2.0
# 4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's            NaN     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
# 3      Bachelor's            NaN     10.938144     Rural          Basic
# 4      Bachelor's  Self-Employed     20.376094     Rural        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# ...

# %%
import pandas as pd

# Load your data
# data = pd.read_csv('your_dataset.csv')  # Uncomment and specify your file path

# Helper function for filling missing values and mapping
def fill_and_map(data, column, fill_value, mapping):
    data[column] = data[column].fillna(fill_value)
    data[column] = data[column].replace(mapping)
    return data

# Gender mapping
data['Gender'] = data['Gender'].replace({'Male': 1, 'Female': 2})

# Marital Status mapping
data = fill_and_map(data, 'Marital Status', 'Unknown', {'Married': 1, 'Divorced': 0, 'Single': 2, 'Unknown': -1})

# Number of Dependents mapping
data = fill_and_map(data, 'Number of Dependents', 'Unknown', {'Unknown': -1})

# Annual Income mapping
data = fill_and_map(data, 'Annual Income', 'Unknown', {'Unknown': -1})

# Age mapping
data = fill_and_map(data, 'Age', 'Unknown', {'Unknown': -1})

# Education Level mapping
data['Education Level'] = data['Education Level'].replace({'Bachelor\'s': 1, 'High School': 2, 'Master\'s': 3, 'PhD': 0})

# Occupation mapping
data = fill_and_map(data, 'Occupation', 'Unknown', {'Employed': 1, 'Unemployed': 0, 'Self-Employed': 2, 'Unknown': -1})

# Health Score mapping
data = fill_and_map(data, 'Health Score', 'Unknown', {'Unknown': -1})

# Location mapping
data['Location'] = data['Location'].replace({'Urban': 1, 'Rural': 2, 'Suburban': 3})

# Policy Type mapping
data['Policy Type'] = data['Policy Type'].replace({'Basic': 1, 'Comprehensive': 2, 'Premium': 3})

# Previous Claims mapping
data = fill_and_map(data, 'Previous Claims', 'Unknown', {'Unknown': -1})

# Vehicle Age mapping
data = fill_and_map(data, 'Vehicle Age', 'Unknown', {'Unknown': -1})

# Credit Score mapping
data = fill_and_map(data, 'Credit Score', 'Unknown', {'Unknown': -1})

# Insurance Duration mapping
data = fill_and_map(data, 'Insurance Duration', 'Unknown', {'Unknown': -1})

# Customer Feedback mapping
data = fill_and_map(data, 'Customer Feedback', 'Unknown', {'Average': 1, 'Poor': 0, 'Good': 2, 'Unknown': -1})

# Smoking Status mapping
data['Smoking Status'] = data['Smoking Status'].replace({'Yes': 1, 'No': 0})

# Exercise Frequency mapping
data['Exercise Frequency'] = data['Exercise Frequency'].replace({'Monthly': 1, 'Weekly': 2, 'Daily': 3, 'Rarely': 0})

# Property Type mapping
data['Property Type'] = data['Property Type'].replace({'House': 1, 'Condo': 2, 'Apartment': 3})

# Display transformed data (optional)
# print(data.head())

# Export the transformed data if required
# data.to_csv('processed_data.csv', index=False)  # Uncomment to save the transformed dataset
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9212\4155079205.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Gender'] = data['Gender'].replace({'Male': 1, 'Female': 2})
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9212\4155079205.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].replace(mapping)
# ...

# %%
data['Policy Start Date'].value_counts()
# Out:
# Policy Start Date
# 2020-02-08 15:21:39.134960    142
# 2023-08-13 15:21:39.155231    137
# 2022-02-02 15:21:39.134960    137
# 2022-08-30 15:21:39.134960    134
# 2023-11-02 15:21:39.134960    118
#                              ...
# 2021-06-07 15:21:39.104139      1
# 2024-07-19 15:21:39.233998      1
# 2019-12-14 15:21:39.110557      1
# 2020-07-23 15:21:39.217387      1
# 2020-10-19 15:21:39.118178      1
# Name: count, Length: 167381, dtype: int64

# %%
data.head()
# Out:
#     Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0  19.0       2        10049.0               1                   1.0
# 1  39.0       2        31678.0               0                   3.0
# 2  23.0       1        25602.0               0                   3.0
# 3  21.0       1       141855.0               1                   2.0
# 4  21.0       1        39651.0               2                   1.0
#
#    Education Level  Occupation  Health Score  Location  Policy Type  \
# 0                1           2     22.598761         1            3
# 1                3          -1     15.569731         2            2
# 2                2           2     47.177549         3            3
# 3                1          -1     10.938144         2            1
# 4                1           2     20.376094         2            3
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0        19.0       2        10049.0               1                   1.0
# 1        39.0       2        31678.0               0                   3.0
# 2        23.0       1        25602.0               0                   3.0
# 3        21.0       1       141855.0               1                   2.0
# 4        21.0       1        39651.0               2                   1.0
# ...       ...     ...            ...             ...                   ...
# 1199995  36.0       2        27316.0               1                   0.0
# 1199996  54.0       1        35786.0               0                  -1.0
# 1199997  19.0       1        51884.0               0                   0.0
# 1199998  55.0       1           -1.0               2                   1.0
# 1199999  21.0       2           -1.0               0                   0.0
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Assuming X is your feature matrix
# 1. Handle datetime columns
if 'Policy Start Date' in data.columns:
    data['Policy Start Date'] = pd.to_datetime(data['Policy Start Date'])
    data['Policy Start Date'] = data['Policy Start Date'].apply(lambda x: x.timestamp())

# 2. Encode categorical columns
categorical_cols = data.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# 3. Handle missing values
data = data.fillna(0)

# %%
data.head()
# Out:
#     Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0  19.0       2        10049.0               1                   1.0
# 1  39.0       2        31678.0               0                   3.0
# 2  23.0       1        25602.0               0                   3.0
# 3  21.0       1       141855.0               1                   2.0
# 4  21.0       1        39651.0               2                   1.0
#
#    Education Level  Occupation  Health Score  Location  Policy Type  \
# 0                1           2     22.598761         1            3
# 1                3          -1     15.569731         2            2
# 2                2           2     47.177549         3            3
# 3                1          -1     10.938144         2            1
# 4                1           2     20.376094         2            3
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# ...

# %%
test=pd.read_csv(r"D:\target\chalnges\kaggle_Regression_with_an_Insurance_Dataset\playground-series-s4e12\test.csv")

# %%
test['Gender'] = test['Gender'].replace({'Male': 1, 'Female': 2})



# Marital Status mapping
test = fill_and_map(test, 'Marital Status', 'Unknown', {'Married': 1, 'Divorced': 0, 'Single': 2, 'Unknown': -1})

# Number of Dependents mapping
test = fill_and_map(test, 'Number of Dependents', 'Unknown', {'Unknown': -1})

# Annual Income mapping
test = fill_and_map(test, 'Annual Income', 'Unknown', {'Unknown': -1})

# Age mapping
test = fill_and_map(test, 'Age', 'Unknown', {'Unknown': -1})

# Education Level mapping
test['Education Level'] = test['Education Level'].replace({'Bachelor\'s': 1, 'High School': 2, 'Master\'s': 3, 'PhD': 0})

# Occupation mapping
test = fill_and_map(test, 'Occupation', 'Unknown', {'Employed': 1, 'Unemployed': 0, 'Self-Employed': 2, 'Unknown': -1})

# Health Score mapping
test = fill_and_map(test, 'Health Score', 'Unknown', {'Unknown': -1})

# Location mapping
test['Location'] = test['Location'].replace({'Urban': 1, 'Rural': 2, 'Suburban': 3})

# Policy Type mapping
test['Policy Type'] = test['Policy Type'].replace({'Basic': 1, 'Comprehensive': 2, 'Premium': 3})

# Previous Claims mapping
test = fill_and_map(test, 'Previous Claims', 'Unknown', {'Unknown': -1})

# Vehicle Age mapping
test = fill_and_map(test, 'Vehicle Age', 'Unknown', {'Unknown': -1})

# Credit Score mapping
test = fill_and_map(test, 'Credit Score', 'Unknown', {'Unknown': -1})

# Insurance Duration mapping
test = fill_and_map(test, 'Insurance Duration', 'Unknown', {'Unknown': -1})

# Customer Feedback mapping
test = fill_and_map(test, 'Customer Feedback', 'Unknown', {'Average': 1, 'Poor': 0, 'Good': 2, 'Unknown': -1})

# Smoking Status mapping
test['Smoking Status'] = test['Smoking Status'].replace({'Yes': 1, 'No': 0})

# Exercise Frequency mapping
test['Exercise Frequency'] = test['Exercise Frequency'].replace({'Monthly': 1, 'Weekly': 2, 'Daily': 3, 'Rarely': 0})

# Property Type mapping
test['Property Type'] = test['Property Type'].replace({'House': 1, 'Condo': 2, 'Apartment': 3})
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9212\947718320.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test['Gender'] = test['Gender'].replace({'Male': 1, 'Female': 2})
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9212\4155079205.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column] = data[column].replace(mapping)
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Assuming X is your feature matrix
# 1. Handle datetime columns
if 'Policy Start Date' in test.columns:
    test['Policy Start Date'] = pd.to_datetime(test['Policy Start Date'])
    test['Policy Start Date'] = test['Policy Start Date'].apply(lambda x: x.timestamp())

# 2. Encode categorical columns
categorical_cols = test.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    le = LabelEncoder()
    test[col] = le.fit_transform(test[col])

# 3. Handle missing values
test = test.fillna(0)

# %%
print(test.columns)
# Out:
# Index(['id', 'Age', 'Gender', 'Annual Income', 'Marital Status',
#        'Number of Dependents', 'Education Level', 'Occupation', 'Health Score',
#        'Location', 'Policy Type', 'Previous Claims', 'Vehicle Age',
#        'Credit Score', 'Insurance Duration', 'Policy Start Date',
#        'Customer Feedback', 'Smoking Status', 'Exercise Frequency',
#        'Property Type'],
#       dtype='object')

# %%
# Save the ID column from test data (for submission)
test_ids = test['id']  # Replace 'Id' with the actual identifier column name in your test set
X_test_full = test.drop(columns=['id'])  # Exclude the identifier column

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X_train_full = data.drop(columns=['Premium Amount'])
y_train_full = data['Premium Amount']

# %%
# Feature scaling
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_full)
X_test_scaled = scaler.transform(X_test_full)

# %%
# Model training
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_scaled, y_train_full)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Generate predictions for the test data
test_predictions = rf_model.predict(X_test_scaled)

# %%
# Create a submission DataFrame
submission = pd.DataFrame({
    'id': test_ids,  # Ensure this matches the ID column in your test data
    'Premium Amount': test_predictions  # Replace with the actual target column name
})

# %%
output_path = r'D:\target\chalnges\kaggle_Regression_with_an_Insurance_Dataset\attempt2\submission.csv'
submission.to_csv(output_path, index=False)
print(f"Submission file saved as '{output_path}'.")
# Out:
# Submission file saved as 'D:\target\chalnges\kaggle_Regression_with_an_Insurance_Dataset\attempt2\submission.csv'.
